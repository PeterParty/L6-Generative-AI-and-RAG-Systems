# %% [markdown]
# [LlamaIndex Crash Course - AI Agents in Python](https://youtu.be/dkisb6FlU-g?si=Mn19ukcQrFfgFfS4)
#
# [Ollama and LLamaIndex](https://developers.llamaindex.ai/python/framework-api-reference/llms/ollama/)
#
# `pip install llama-index-llms-ollama`

# %%
from llama_index.llms.openai import Ollama
llm = Ollama(model="gemma3",request_timeout=60.0)

response =llm.complete("What is the capital of Bucharest?")

print(response)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from llama_index.llms.openai import Ollama
#       2 llm = Ollama(model="gemma3",request_timeout=60.0)
#       3
#       4 response =llm.complete("What is the capital of Bucharest?")
#
# ImportError: cannot import name 'Ollama' from 'llama_index.llms.openai' (/home/petrisor/Desktop/anul3Sem2/PracticaDeSpecialitate/L6-Generative-AI-and-RAG-Systems/.venv2/lib64/python3.12/site-packages/llama_index/llms/openai/__init__.py)

# %%
import sys
# !{sys.executable} -m pip install llama-index
# Out:
# ...
#   Using cached llama_index_core-0.14.23-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached nltk-3.10.2-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached aiosqlite-0.22.1-py3-none-any.whl.metadata (4.3 kB)
# ...
#   Using cached banks-2.5.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# ...
#   Using cached deprecated-1.3.1-py2.py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached dirtyjson-1.0.8-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached llama_index_workflows-2.23.0-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# ...
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached pillow-12.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# ...
#   Using cached setuptools-84.0.0-py3-none-any.whl.metadata (6.6 kB)
# ...
