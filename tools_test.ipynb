# %% [markdown]
# # Test openAI Api key

# %% [markdown]
# `pip install openai`

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv, dotenv_values

load_dotenv()

client = OpenAI(
    api_key =os.getenv("OPEN_AI_API_KEY")
)

response = client.responses.create(
    model = "gpt-5.4-mini",
    input = "write a haiku about ai",
    store = True,
)

print(response.output_text)
# Out:
# Silent circuits hum
# Thought blooms in electric dawn
# Code dreams learn to sing

# %% [markdown]
# Mergee!

# %% [markdown]
# # Testare LangChain
#
# Instalare biblioteca:
#
# ~~`pip install -U langchain deepagents`~~
# ERROR:Could not find a version that satisfies the requirement depagents(from versions: none)
#
# `pip install -qU langchain "langchain[openai]"`
#
# Creare a unui agent

# %%
from langchain.agents import create_agent
# from dotenv import load_dotenv

# load_dotenv()

def get_weather(city: str) -> str:
    """Get weather for a given city."""
    return f"It's always sunny in {city}!"

agent = create_agent(
    # modelul se poate modifica 
    model="ollama:gemma3:latest",
    tools=[get_weather],
    system_prompt="You are a helpful assistant",
)

result = agent.invoke(
    {"messages": [{"role": "user", "content": "What's the weather in San Francisco?"}]}
)
print(result["messages"][-1].content_blocks)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from langchain.agents import create_agent
#       2 # from dotenv import load_dotenv
#       3
#       4 # load_dotenv()
#
# ImportError: cannot import name 'create_agent' from 'langchain.agents' (/home/petrisor/Desktop/anul3Sem2/PracticaDeSpecialitate/L6-Generative-AI-and-RAG-Systems/.venv/lib64/python3.12/site-packages/langchain/agents/__init__.py)

# %% [markdown]
# LlamaIndex

# %% [markdown]
# `pip install llama-index`

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
import os
from dotenv import load_dotenv

load_dotenv()

documents = SimpleDirectoryReader("data").load_data()
index = VectorStoreIndex.from_documents(documents)
query_engine = index.as_query_engine()
response = query_engine.query("Some question about the data should go here")
print(response)
# Out:
# Retrying llama_index.embeddings.openai.base.OpenAIEmbedding._get_text_embeddings.<locals>._retryable_get_embeddings in 1 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'You have no credits remaining. Add credits to continue using the API at https://platform.openai.com/settings/organization/billing/.', 'type': 'insufficient_quota', 'param': None, 'code': 'credit_balance_exhausted'}}.
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[15], line 8
#       4
#       5 load_dotenv()
#       6
#       7 documents = SimpleDirectoryReader("data").load_data()
# ----> 8 index = VectorStoreIndex.from_documents(documents)
#       9 query_engine = index.as_query_engine()
#      10 response = query_engine.query("Some question about the data should go here")
#      11 print(response)
#
# File /mnt/g/facultate/anul 3 sem 2/Practica de specialiate/L6-Generative AI & RAG Systems/.venv2/lib/python3.14/site-packages/llama_index/core/indices/base.py:122, in BaseIndex.from_documents(cls, documents, storage_context, show_progress, callback_manager, transformations, **kwargs)
#     113     docstore.set_document_hash(doc.id_, doc.hash)
#     115 nodes = run_transformations(
#     116     documents,  # type: ignore
#     117     transformations,
#     118     show_progress=show_progress,
#     119     **kwargs,
#     120 )
# --> 122 return cls(
#     123     nodes=nodes,
#     124     storage_context=storage_context,
#     125     callback_manager=callback_manager,
#     126     show_progress=show_progress,
#     127     transformations=transformations,
#     128     **kwargs,
#     129 )
#
# File /mnt/g/facultate/anul 3 sem 2/Practica de specialiate/L6-Generative AI & RAG Systems/.venv2/lib/python3.14/site-packages/llama_index/core/indices/vector_store/base.py:75, in VectorStoreIndex.__init__(self, nodes, use_async, store_nodes_override, embed_model, insert_batch_size, objects, index_struct, storage_context, callback_manager, transformations, show_progress, **kwargs)
#      70 self._embed_model = resolve_embed_model(
#      71     embed_model or Settings.embed_model, callback_manager=callback_manager
#      72 )
#      74 self._insert_batch_size = insert_batch_size
# ---> 75 super().__init__(
#      76     nodes=nodes,
#      77     index_struct=index_struct,
#      78     storage_context=storage_context,
#      79     show_progress=show_progress,
#      80     objects=objects,
#      81     callback_manager=callback_manager,
#      82     transformations=transformations,
#      83     **kwargs,
#      84 )
#
# File /mnt/g/facultate/anul 3 sem 2/Practica de specialiate/L6-Generative AI & RAG Systems/.venv2/lib/python3.14/site-packages/llama_index/core/indices/base.py:79, in BaseIndex.__init__(self, nodes, objects, index_struct, storage_context, callback_manager, transformations, show_progress, **kwargs)
#      77 if index_struct is None:
#      78     nodes = nodes or []
# ---> 79     index_struct = self.build_index_from_nodes(
#      80         nodes + objects,  # type: ignore
#      81         **kwargs,  # type: ignore
#      82     )
#      83 self._index_struct = index_struct
#      84 self._storage_context.index_store.add_index_struct(self._index_struct)
#
# File /mnt/g/facultate/anul 3 sem 2/Practica de specialiate/L6-Generative AI & RAG Systems/.venv2/lib/python3.14/site-packages/llama_index/core/indices/vector_store/base.py:309, in VectorStoreIndex.build_index_from_nodes(self, nodes, **insert_kwargs)
#     306 if len(content_nodes) != len(nodes):
#     307     print("Some nodes are missing content, skipping them...")
# --> 309 return self._build_index_from_nodes(content_nodes, **insert_kwargs)
#
# File /mnt/g/facultate/anul 3 sem 2/Practica de specialiate/L6-Generative AI & RAG Systems/.venv2/lib/python3.14/site-packages/llama_index/core/indices/vector_store/base.py:278, in VectorStoreIndex._build_index_from_nodes(self, nodes, **insert_kwargs)
#     276     run_async_tasks(tasks)
#     277 else:
# --> 278     self._add_nodes_to_index(
#     279         index_struct,
#     280         nodes,
#     281         show_progress=self._show_progress,
#     282         **insert_kwargs,
#     283     )
#     284 return index_struct
#
# File /mnt/g/facultate/anul 3 sem 2/Practica de specialiate/L6-Generative AI & RAG Systems/.venv2/lib/python3.14/site-packages/llama_index/core/indices/vector_store/base.py:231, in VectorStoreIndex._add_nodes_to_index(self, index_struct, nodes, show_progress, **insert_kwargs)
#     228     return
#     230 for nodes_batch in iter_batch(nodes, self._insert_batch_size):
# --> 231     nodes_batch = self._get_node_with_embedding(nodes_batch, show_progress)
#     232     new_ids = self._vector_store.add(nodes_batch, **insert_kwargs)
#     234     if not self._vector_store.stores_text or self._store_nodes_override:
#     235         # NOTE: if the vector store doesn't store text,
#     236         # we need to add the nodes to the index struct and document store
#
# File /mnt/g/facultate/anul 3 sem 2/Practica de specialiate/L6-Generative AI & RAG Systems/.venv2/lib/python3.14/site-packages/llama_index/core/indices/vector_store/base.py:138, in VectorStoreIndex._get_node_with_embedding(self, nodes, show_progress)
#     126 def _get_node_with_embedding(
#     127     self,
#     128     nodes: Sequence[BaseNode],
#     129     show_progress: bool = False,
#     130 ) -> List[BaseNode]:
#     131     """
#     132     Get tuples of id, node, and embedding.
#     133
#    (...)    136
#     137     """
# --> 138     id_to_embed_map = embed_nodes(
#     139         nodes, self._embed_model, show_progress=show_progress
#     140     )
#     142     results = []
#     143     for node in nodes:
#
# File /mnt/g/facultate/anul 3 sem 2/Practica de specialiate/L6-Generative AI & RAG Systems/.venv2/lib/python3.14/site-packages/llama_index/core/indices/utils.py:196, in embed_nodes(nodes, embed_model, show_progress)
#     193     else:
#     194         id_to_embed_map[node.node_id] = node.embedding
# --> 196 new_embeddings = embed_model.get_text_embedding_batch(
#     197     texts_to_embed, show_progress=show_progress
#     198 )
#     200 for new_id, text_embedding in zip(ids_to_embed, new_embeddings):
#     201     id_to_embed_map[new_id] = text_embedding
#
# File /mnt/g/facultate/anul 3 sem 2/Practica de specialiate/L6-Generative AI & RAG Systems/.venv2/lib/python3.14/site-packages/llama_index_instrumentation/dispatcher.py:413, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     410             _logger.debug(f"Failed to reset active_span_id: {e}")
#     412 try:
# --> 413     result = func(*args, **kwargs)
#     414     if isinstance(result, asyncio.Future):
#     415         # If the result is a Future, wrap it
#     416         new_future = asyncio.ensure_future(result)
#
# File /mnt/g/facultate/anul 3 sem 2/Practica de specialiate/L6-Generative AI & RAG Systems/.venv2/lib/python3.14/site-packages/llama_index/core/base/embeddings/base.py:517, in BaseEmbedding.get_text_embedding_batch(self, texts, show_progress, **kwargs)
#     515     self.rate_limiter.acquire()
#     516 if not self.embeddings_cache:
# --> 517     embeddings = self._get_text_embeddings(cur_batch)
#     518 elif self.embeddings_cache is not None:
#     519     embeddings = self._get_text_embeddings_cached(cur_batch)
#
# File /mnt/g/facultate/anul 3 sem 2/Practica de specialiate/L6-Generative AI & RAG Systems/.venv2/lib/python3.14/site-packages/llama_index/embeddings/openai/base.py:472, in OpenAIEmbedding._get_text_embeddings(self, texts)
#     463 @retry_decorator
#     464 def _retryable_get_embeddings():
#     465     return get_embeddings(
#     466         client,
#     467         texts,
#     468         engine=self._text_engine,
#     469         **self.additional_kwargs,
#     470     )
# --> 472 return _retryable_get_embeddings()
#
# File /mnt/g/facultate/anul 3 sem 2/Practica de specialiate/L6-Generative AI & RAG Systems/.venv2/lib/python3.14/site-packages/tenacity/__init__.py:331, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     329 copy = self.copy()
#     330 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 331 return copy(f, *args, **kw)
#
# File /mnt/g/facultate/anul 3 sem 2/Practica de specialiate/L6-Generative AI & RAG Systems/.venv2/lib/python3.14/site-packages/tenacity/__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File /mnt/g/facultate/anul 3 sem 2/Practica de specialiate/L6-Generative AI & RAG Systems/.venv2/lib/python3.14/site-packages/tenacity/__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File /mnt/g/facultate/anul 3 sem 2/Practica de specialiate/L6-Generative AI & RAG Systems/.venv2/lib/python3.14/site-packages/tenacity/__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     411 retry_exc = self.retry_error_cls(fut)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File /mnt/g/facultate/anul 3 sem 2/Practica de specialiate/L6-Generative AI & RAG Systems/.venv2/lib/python3.14/site-packages/tenacity/__init__.py:184, in RetryError.reraise(self)
#     182 def reraise(self) -> t.NoReturn:
#     183     if self.last_attempt.failed:
# --> 184         raise self.last_attempt.result()
#     185     raise self
#
# File /usr/local/lib/python3.14/concurrent/futures/_base.py:443, in Future.result(self, timeout)
#     441     raise CancelledError()
#     442 elif self._state == FINISHED:
# --> 443     return self.__get_result()
#     445 self._condition.wait(timeout)
#     447 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /usr/local/lib/python3.14/concurrent/futures/_base.py:395, in Future.__get_result(self)
#     393 if self._exception is not None:
#     394     try:
# --> 395         raise self._exception
#     396     finally:
#     397         # Break a reference cycle with the exception in self._exception
#     398         self = None
#
# File /mnt/g/facultate/anul 3 sem 2/Practica de specialiate/L6-Generative AI & RAG Systems/.venv2/lib/python3.14/site-packages/tenacity/__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File /mnt/g/facultate/anul 3 sem 2/Practica de specialiate/L6-Generative AI & RAG Systems/.venv2/lib/python3.14/site-packages/llama_index/embeddings/openai/base.py:465, in OpenAIEmbedding._get_text_embeddings.<locals>._retryable_get_embeddings()
#     463 @retry_decorator
#     464 def _retryable_get_embeddings():
# --> 465     return get_embeddings(
#     466         client,
#     467         texts,
#     468         engine=self._text_engine,
#     469         **self.additional_kwargs,
#     470     )
#
# File /mnt/g/facultate/anul 3 sem 2/Practica de specialiate/L6-Generative AI & RAG Systems/.venv2/lib/python3.14/site-packages/llama_index/embeddings/openai/base.py:172, in get_embeddings(client, list_of_text, engine, **kwargs)
#     168 assert len(list_of_text) <= 2048, "The batch size should not be larger than 2048."
#     170 list_of_text = [text.replace("\n", " ") for text in list_of_text]
# --> 172 data = client.embeddings.create(input=list_of_text, model=engine, **kwargs).data
#     173 return [d.embedding for d in data]
#
# File /mnt/g/facultate/anul 3 sem 2/Practica de specialiate/L6-Generative AI & RAG Systems/.venv2/lib/python3.14/site-packages/openai/resources/embeddings.py:136, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     130             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     131                 base64.b64decode(data), dtype="float32"
#     132             ).tolist()
#     134     return obj
# --> 136 return self._post(
#     137     "/embeddings",
#     138     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     139     options=make_request_options(
#     140         extra_headers=extra_headers,
#     141         extra_query=extra_query,
#     142         extra_body=extra_body,
#     143         timeout=timeout,
#     144         post_parser=parser,
#     145         security={"bearer_auth": True},
#     146     ),
#     147     cast_to=CreateEmbeddingResponse,
#     148 )
#
# File /mnt/g/facultate/anul 3 sem 2/Practica de specialiate/L6-Generative AI & RAG Systems/.venv2/lib/python3.14/site-packages/openai/_base_client.py:1375, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1366     warnings.warn(
#    1367         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1368         "Please pass raw bytes via the `content` parameter instead.",
#    1369         DeprecationWarning,
#    1370         stacklevel=2,
#    1371     )
#    1372 opts = FinalRequestOptions.construct(
#    1373     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1374 )
# -> 1375 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /mnt/g/facultate/anul 3 sem 2/Practica de specialiate/L6-Generative AI & RAG Systems/.venv2/lib/python3.14/site-packages/openai/_base_client.py:1148, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1145             err.response.read()
#    1147         log.debug("Re-raising status error")
# -> 1148         raise self._make_status_error_from_response(err.response) from None
#    1150     break
#    1152 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You have no credits remaining. Add credits to continue using the API at https://platform.openai.com/settings/organization/billing/.', 'type': 'insufficient_quota', 'param': None, 'code': 'credit_balance_exhausted'}}

# %%
print("ceva")
# Out:
# ceva
